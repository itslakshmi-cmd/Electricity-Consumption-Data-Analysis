# %%
import pandas as pd

# %%
df=pd.read_csv('GlobalCO2Emissions.csv')
df
# Out:
#     Year  Emissions
# 0   1750       0.03
# 1   1760       0.03
# 2   1770       0.03
# 3   1780       0.03
# 4   1790       0.04
# 5   1800       0.04
# 6   1810       0.05
# 7   1820       0.06
# 8   1830       0.07
# 9   1840       0.09
# 10  1850       0.11
# 11  1860       0.14
# 12  1870       0.19
# 13  1880       0.28
# 14  1890       0.43
# 15  1900       0.60
# 16  1910       0.81
# 17  1920       1.07
# 18  1930       1.38
# 19  1940       1.71
# 20  1950       2.34
# 21  1960       3.74
# 22  1970       6.73
# 23  1980      10.40
# 24  1990      14.45
# 25  2000      20.64
# 26  2010      28.65
# 27  2022      37.15
# 28  2023      40.90

# %%
import seaborn as sns
sns.pairplot(df)

# %%
y=df['Emissions']
x=df.drop('Emissions',axis=1)
x
# Out:
#     Year
# 0   1750
# 1   1760
# 2   1770
# 3   1780
# 4   1790
# 5   1800
# 6   1810
# 7   1820
# 8   1830
# 9   1840
# 10  1850
# 11  1860
# 12  1870
# 13  1880
# 14  1890
# 15  1900
# 16  1910
# 17  1920
# 18  1930
# 19  1940
# 20  1950
# 21  1960
# 22  1970
# 23  1980
# 24  1990
# 25  2000
# 26  2010
# 27  2022
# 28  2023

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=25)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((23, 1), (6, 1), (23,), (6,))

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
y_pred[:5]
# Out:
# array([ 9.89979461,  2.84561346, -5.09034033,  1.08206817, 14.30865782])

# %%
y_test[:5]
# Out:
# 19     1.71
# 11     0.14
# 2      0.03
# 9      0.09
# 24    14.45
# Name: Emissions, dtype: float64

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
round(r2_score(y_test,y_pred),2)
# Out:
# 0.55

# %%
df.dtypes
# Out:
# Year           int64
# Emissions    float64
# dtype: object

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,root_mean_squared_error
mean_squared_error(y_test,y_pred)
# Out:
# 83.73371957436818

# %%
root_mean_squared_error(y_test,y_pred)
# Out:
# 9.15061307095695

# %%
model.coef_
# Out:
# array([0.06993092])

# %%
model.intercept_
# Out:
# np.float64(-127.420072103974)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
y_pred=model.predict([[130]])
y_pred
# Out:
# c:\Users\asus\Python_app\DAV\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([-149.70105384])
